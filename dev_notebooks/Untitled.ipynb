# %%
 #Load the file
import numpy as np
data = np.load('/home/lonce/slowdisk/data/ProceduralEngineSounds/ECDC/C_full_set_ecdc/001_Engine-C.cond.npy')

# Check shape and basic info
print(f"Shape: {data.shape}")
print(f"Data type: {data.dtype}")
print(f"Number of rows: {data.shape[0]}")
print(f"Number of columns: {data.shape[1]}")

# View first few rows
print(data[:5])  # First 5 rows
# Out:
# Shape: (923, 2)
# Data type: float16
# Number of rows: 923
# Number of columns: 2
# [[ 9.690e+02 -1.324e+01]
#  [ 2.104e+03 -2.892e+01]
#  [ 1.847e+03 -2.481e+01]
#  [ 1.981e+03 -2.639e+01]
#  [ 1.894e+03 -2.597e+01]]
