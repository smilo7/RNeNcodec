# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "quickstart") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
timestamp = datetime.now().strftime("%y.%m.%d.%H.%M")

# dataset_path      = "../data/quickstartdata/waterfill"      # Path to dataset directory
dataset_path = "/home/am/Documents/upf_smc/yr2/thesis/code/encodec_bandwith_extension/data/keyboard"
output_model_path = "checkpoints/output_"+timestamp # Path to save the trained model and configs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from training.loop import train_model

results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 4,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)

# %%
from training.loop import train_model
results = train_model(
    dataset_path      = dataset_path,
    model_output_path = "output_keyboard_smoketest",
    num_epochs        = 30,     # small data -> watch for overfit; this is a smoke test
    batch_size        = 32,     # lower than the 100 default given little data
    sequence_length   = 125,    # ~1.7s of tokens
    batches_per_epoch = 50,
    learning_rate     = 0.005,
    hidden_size       = 128,
    num_layers        = 3,
    save_interval     = 10,
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: typing_rate
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Cascade mode: soft
#     Tau (soft): 0.6
# 📋 Copied conditioning_config.json to model directory
# saved to /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_smoketest/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_smoketest
# 💾 Saved configuration to: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_smoketest/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 30
# Batches per epoch: 50
# Batch size: 32
# TF schedule: [25, 25]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_smoketest/tensorboard
# ======================================================================
# Epoch   1/30 | TF=ON | Training loss: 34.1933
# Epoch   2/30 | TF=ON | Training loss: 30.2915
# Epoch   3/30 | TF=ON | Training loss: 28.7649
# Epoch   4/30 | TF=ON | Training loss: 27.5695
# Epoch   5/30 | TF=ON | Training loss: 27.0414
# Epoch   6/30 | TF=ON | Training loss: 26.5960
# Epoch   7/30 | TF=ON | Training loss: 26.2255
# Epoch   8/30 | TF=ON | Training loss: 25.9085
# Epoch   9/30 | TF=ON | Training loss: 25.5252
# Epoch  10/30 | TF=ON | Training loss: 25.1514
#    💾 Checkpoint saved at epoch 10
# Epoch  11/30 | TF=ON | Training loss: 24.7783
# Epoch  12/30 | TF=ON | Training loss: 24.3687
# Epoch  13/30 | TF=ON | Training loss: 23.9450
# Epoch  14/30 | TF=ON | Training loss: 23.6721
# Epoch  15/30 | TF=ON | Training loss: 23.2683
# Epoch  16/30 | TF=ON | Training loss: 22.9256
# Epoch  17/30 | TF=ON | Training loss: 22.5905
# Epoch  18/30 | TF=ON | Training loss: 22.3560
# Epoch  19/30 | TF=ON | Training loss: 22.0215
# Epoch  20/30 | TF=ON | Training loss: 21.7659
#    💾 Checkpoint saved at epoch 20
# Epoch  21/30 | TF=ON | Training loss: 21.4612
# Epoch  22/30 | TF=ON | Training loss: 21.2324
# Epoch  23/30 | TF=ON | Training loss: 20.9667
# Epoch  24/30 | TF=ON | Training loss: 20.7603
# Epoch  25/30 | TF=ON | Training loss: 20.5192
# Epoch  26/30 | TF=OFF | Training loss: 29.1139
# Epoch  27/30 | TF=OFF | Training loss: 27.0376
# Epoch  28/30 | TF=OFF | Training loss: 26.2774
# Epoch  29/30 | TF=OFF | Training loss: 25.8269
# Epoch  30/30 | TF=OFF | Training loss: 25.4765
#    💾 Checkpoint saved at epoch 30
#
# 🏋️ Training Completed
#
# Total time: 00:16:12
# Model saved to: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_smoketest
# ======================================================================

# %%
# RNeNcodec repo (rnencodec env), quickstart/2_train.ipynb:
from training.loop import train_model
train_model(
    dataset_path      = "/home/am/Documents/upf_smc/yr2/thesis/code/encodec_bandwith_extension/data/keyboard",
    model_output_path = "output_keyboard_12kbps",
    num_epochs=30, batch_size=32, sequence_length=125, hidden_size=128, num_layers=3,
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: typing_rate
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Cascade mode: soft
#     Tau (soft): 0.6
# 📋 Copied conditioning_config.json to model directory
# saved to /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps
# 💾 Saved configuration to: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 30
# Batches per epoch: 100
# Batch size: 32
# TF schedule: [25, 25]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps/tensorboard
# ======================================================================
# Epoch   1/30 | TF=ON | Training loss: 32.2542
# Epoch   2/30 | TF=ON | Training loss: 29.2833
# Epoch   3/30 | TF=ON | Training loss: 27.5336
# Epoch   4/30 | TF=ON | Training loss: 26.6067
# Epoch   5/30 | TF=ON | Training loss: 25.9331
# Epoch   6/30 | TF=ON | Training loss: 25.2454
# Epoch   7/30 | TF=ON | Training loss: 24.5588
# Epoch   8/30 | TF=ON | Training loss: 23.8471
# Epoch   9/30 | TF=ON | Training loss: 23.3021
# Epoch  10/30 | TF=ON | Training loss: 22.8159
# Epoch  11/30 | TF=ON | Training loss: 22.3856
# Epoch  12/30 | TF=ON | Training loss: 22.0160
# Epoch  13/30 | TF=ON | Training loss: 21.6134
# Epoch  14/30 | TF=ON | Training loss: 21.2878
# Epoch  15/30 | TF=ON | Training loss: 20.9813
# Epoch  16/30 | TF=ON | Training loss: 20.7430
# Epoch  17/30 | TF=ON | Training loss: 20.4755
# Epoch  18/30 | TF=ON | Training loss: 20.2802
# Epoch  19/30 | TF=ON | Training loss: 20.0751
# Epoch  20/30 | TF=ON | Training loss: 19.8680
# Epoch  21/30 | TF=ON | Training loss: 19.7030
# Epoch  22/30 | TF=ON | Training loss: 19.5507
# Epoch  23/30 | TF=ON | Training loss: 19.3753
# Epoch  24/30 | TF=ON | Training loss: 19.2440
# Epoch  25/30 | TF=ON | Training loss: 19.0654
#    💾 Checkpoint saved at epoch 25
# Epoch  26/30 | TF=OFF | Training loss: 30.5698
# Epoch  27/30 | TF=OFF | Training loss: 26.4159
# Epoch  28/30 | TF=OFF | Training loss: 25.4109
# Epoch  29/30 | TF=OFF | Training loss: 24.7976
# Epoch  30/30 | TF=OFF | Training loss: 24.4596
#
# 🏋️ Training Completed
#
# Total time: 00:44:53
# Model saved to: /home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps
# ======================================================================
# {'output_dir': '/home/am/Documents/upf_smc/yr2/thesis/code/RNeNcodec-main/quickstart/output_keyboard_12kbps',
#  'final_epoch': 30,
#  'elapsed_time': 2693.8688113689423,
#  'device': 'cpu'}
